# %% [markdown]
# #imports

# %%
# !pip install bertopic

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/DS_project"
os.chdir(path)
# Out:
# Mounted at /content/drive

# %%
from bertopic import BERTopic
#from top2vec import Top2Vec
import re
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
import numpy as np
#import umap
#from mpl_toolkits.mplot3d import Axes3D

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# %% [markdown]
# # load csv

# %%
sus_data = pd.read_csv('sus_data.csv')
non_sus_data = pd.read_csv('non_sus_data.csv')
sus_data.head()
# Out:
#    product_id  full_price  discounted  current_price  \
# 0  DX7615-601          57        True          38.97
# 1  DX9176-107          95        True          71.97
# 2  DH3162-100          70       False          70.00
# 3  FN6344-001         120       False         120.00
# 4  DJ6525-002          32       False          32.00
#
#                                          product_url  \
# 0  https://www.nike.com/t/star-runner-4-big-kids-...
# 1  https://www.nike.com/t/gamma-force-womens-shoe...
# 2  https://www.nike.com/t/court-legacy-mens-shoes...
# 3  https://www.nike.com/t/dunk-low-next-nature-se...
# 4  https://www.nike.com/t/alpha-huarache-4-keysto...
#
#                                          description    ratings reviews
# 0  Because ice-cream trucks, games of tag and rac...  4.5 Stars      94
# 1  Layers upon layers of dimensional style—that's...  4.6 Stars     381
# 2  Honoring a history rooted in tennis culture, t...  4.6 Stars     312
# 3  The Dunk returns with classic construction, th...    5 Stars       4
# 4  These game-changers aren’t your grandaddy’s ol...  4.9 Stars     107

# %% [markdown]
# # clean up sus descriptions (remove stopwords, lemmatize)

# %%
stop_words = set(stopwords.words('english'))
# add additional stopwords
additional_stopwords = {'nike', 'air', 'shoe', 'design'}
stop_words = set(stopwords.words('english')).union(additional_stopwords)
lemmatizer = WordNetLemmatizer()

def preprocess_text(text: str) -> str:
    # Remove links
    text = re.sub(r"http\S+", "", text)
    # Remove special chars and numbers
    text = re.sub(r"[^A-Za-z ]+", "", text)
    # Tokenize and remove stopwords
    tokens = nltk.word_tokenize(text.lower())
    tokens = [word for word in tokens if word not in stop_words]
    # Lemmatize
    lemmatized = [lemmatizer.lemmatize(word) for word in tokens]
    # Join tokens back into a string
    text = " ".join(lemmatized)
    return text.strip()

#clean the descriptions (remove stopwords and special characters like ,.-)
sus_data['clean_description'] = sus_data['description'].apply(lambda text: preprocess_text(text))
sus_data.head()
# Out:
#    product_id  full_price  discounted  current_price  \
# 0  DX7615-601          57        True          38.97
# 1  DX9176-107          95        True          71.97
# 2  DH3162-100          70       False          70.00
# 3  FN6344-001         120       False         120.00
# 4  DJ6525-002          32       False          32.00
#
#                                          product_url  \
# 0  https://www.nike.com/t/star-runner-4-big-kids-...
# 1  https://www.nike.com/t/gamma-force-womens-shoe...
# 2  https://www.nike.com/t/court-legacy-mens-shoes...
# 3  https://www.nike.com/t/dunk-low-next-nature-se...
# 4  https://www.nike.com/t/alpha-huarache-4-keysto...
#
#                                          description    ratings reviews  \
# 0  Because ice-cream trucks, games of tag and rac...  4.5 Stars      94
# 1  Layers upon layers of dimensional style—that's...  4.6 Stars     381
# 2  Honoring a history rooted in tennis culture, t...  4.6 Stars     312
# 3  The Dunk returns with classic construction, th...    5 Stars       4
# 4  These game-changers aren’t your grandaddy’s ol...  4.9 Stars     107
#
#                                    clean_description
# 0  icecream truck game tag race end street back w...
# 1  layer upon layer dimensional stylethats force ...
# 2  honoring history rooted tennis culture court l...
# 3  dunk return classic construction throwback hoo...
# 4  gamechangers arent grandaddys oldschool metal ...

# %% [markdown]
# ## clean up descriptions on non sus data (stop words, lemmatize)

# %%
non_sus_data['clean_description'] = non_sus_data['description'].apply(lambda text: preprocess_text(text))
non_sus_data.head()
# Out:
#    product_id  full_price  discounted  current_price  \
# 0  BQ3207-002          60       False          60.00
# 1  DH3158-108          80        True          60.97
# 2  FV6603-101         110       False         110.00
# 3  FZ4178-010         170        True         102.97
# 4  511417-136         100       False         100.00
#
#                                          product_url  \
# 0  https://www.nike.com/t/revolution-5-womens-roa...
# 1  https://www.nike.com/t/court-vision-low-next-n...
# 2  https://www.nike.com/t/p-6000-shoes-SGxVgg/FV6...
# 3  https://www.nike.com/t/jordan-6-rings-mens-sho...
# 4  https://www.nike.com/t/air-max-correlate-women...
#
#                                          description    ratings reviews  \
# 0  When the road beckons, answer the call in a li...  4.6 Stars    2019
# 1  In love with the classic look of '80s basketba...  4.7 Stars     440
# 2  A mash-up of past Pegasus sneakers, the P-6000...  4.9 Stars     185
# 3  You don't win six championships without some s...  4.7 Stars       9
# 4  The Nike Air Max Correlate sets you up in thro...  4.6 Stars      99
#
#                                    clean_description
# 0  road beckons answer call lightweight pair that...
# 1  love classic look basketball thing fastpaced c...
# 2  mashup past pegasus sneaker p take early runni...
# 3  dont win six championship without serious skil...
# 4  max correlate set throwback style multitexture...

# %% [markdown]
# # descriptions as lists

# %%
non_sus_descriptions = [each for each in non_sus_data['clean_description']]
sus_descriptions = [each for each in sus_data['clean_description']]

# %%
words_to_remove_sus = {"nike", "air", "youve", 'made', 'shoe', 'jr', 'even', 'take', 'dj', 'looking', 'youre', 'whether','fj','pas'}
words_to_remove_non_sus = {'youll', 'next', 'logo', 'aj', 'youre', 'mj','take','give','whether'}
non_sus_filtered_descriptions = [' '.join(word for word in description.split() if word not in words_to_remove_non_sus) for description in non_sus_descriptions]
sus_filtered_descriptions = [' '.join(word for word in description.split() if word not in words_to_remove_sus) for description in sus_descriptions]

# %% [markdown]
# #initial attempt on sus descriptions

# %%
topic_model = BERTopic(calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(sus_filtered_descriptions)
# Out:
# 2024-05-01 01:14:54,244 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# 2024-05-01 01:15:08,931 - BERTopic - Embedding - Completed ✓
# 2024-05-01 01:15:08,932 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-01 01:15:19,875 - BERTopic - Dimensionality - Completed ✓
# 2024-05-01 01:15:19,877 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-01 01:15:19,902 - BERTopic - Cluster - Completed ✓
# 2024-05-01 01:15:19,911 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-01 01:15:19,953 - BERTopic - Representation - Completed ✓

# %% [markdown]
# ### shows what words represent each topic

# %%
topic_model.visualize_barchart(n_words=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="84d9944e-4c49-41a0-b6ad-a9fe0464d223" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84d9944e-4c49-41a0-b6ad-a9fe0464d223")) {                    Plotly.newPlot(                        "84d9944e-4c49-41a0-b6ad-a9fe0464d223",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.025412747702074634,0.025717266564642936,0.026224793135164223,0.026224793135164223,0.026224793135164223,0.027911439798611416,0.0280664370372761,0.029172092251950752,0.029723962776589584,0.03443715233420764],"y":["material  ","upper  ","comfortable  ","foam  ","new  ","max  ","recycled  ","run  ","comfort  ","cushioning  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.04781573042329693,0.047898534921196154,0.04897157660158499,0.050539998445799726,0.05484626020544389,0.05673647521822232,0.0579404223126383,0.05876589192190199,0.05886666302975593,0.06596291019192557],"y":["skill  ","need  ","get  ","club  ","soccer  ","field  ","help  ","traction  ","lace  ","game  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.06502053180296621,0.06502053180296621,0.06502053180296621,0.06502053180296621,0.06502053180296621,0.06502053180296621,0.06502053180296621,0.06984308137968591,0.10666474861270657,0.10716133232817424],"y":["conforms  ","sleeker  ","sending  ","latest  ","breakawayshown  ","evolve  ","date  ","game  ","legend  ","leather  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.10466212879147549,0.10466212879147549,0.10466212879147549,0.10466212879147549,0.10753426696082481,0.1124959300830264,0.11296791297479974,0.1179937684941947,0.11853588111587919,0.12805186966573837],"y":["finisher  ","organizer  ","assister  ","prime  ","next  ","unscripted  ","cyclone  ","level  ","help  ","phantom  "],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555 ...

# %% [markdown]
# # second attempt BERTopic model on sus descriptions

# %%
train_sus, test_sus = train_test_split(sus_filtered_descriptions, test_size=0.5, random_state=40)

# %%
model_sus= BERTopic(calculate_probabilities=True, verbose=True)
topics, probs = model_sus.fit_transform(train_sus)
model_sus.fit(test_sus)
# Out:
# 2024-05-08 21:44:49,525 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-08 21:44:54,056 - BERTopic - Embedding - Completed ✓
# 2024-05-08 21:44:54,058 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-08 21:44:56,570 - BERTopic - Dimensionality - Completed ✓
# 2024-05-08 21:44:56,573 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-08 21:44:56,587 - BERTopic - Cluster - Completed ✓
# 2024-05-08 21:44:56,593 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-08 21:44:56,616 - BERTopic - Representation - Completed ✓
# 2024-05-08 21:44:56,648 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-08 21:45:00,559 - BERTopic - Embedding - Completed ✓
# 2024-05-08 21:45:00,562 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-08 21:45:04,918 - BERTopic - Dimensionality - Completed ✓
# 2024-05-08 21:45:04,924 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-08 21:45:04,942 - BERTopic - Cluster - Completed ✓
# 2024-05-08 21:45:04,950 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-08 21:45:04,991 - BERTopic - Representation - Completed ✓

# %%
model_sus.visualize_barchart(n_words=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7c824bf3-ffba-499e-8a9d-82fc34dc0f99" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c824bf3-ffba-499e-8a9d-82fc34dc0f99")) {                    Plotly.newPlot(                        "7c824bf3-ffba-499e-8a9d-82fc34dc0f99",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.026148820182043214,0.026572543616417376,0.028133829093397768,0.02815416034845972,0.02898822939972805,0.0294852431673317,0.029582424515456687,0.03328031659532773,0.03413356674860387,0.0369166903610684],"y":["max  ","feel  ","upper  ","help  ","lightweight  ","foam  ","cushioning  ","recycled  ","soft  ","comfort  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.0439143318641925,0.05455417942125922,0.055995200542808966,0.06276312570260016,0.0638128829883253,0.0653017894773182,0.06691742563811265,0.06777682722997551,0.06881913655184382,0.08266270225884502],"y":["soccer  ","next  ","every  ","skill  ","need  ","cleat  ","help  ","traction  ","field  ","game  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.06874684095406326,0.06874684095406326,0.06874684095406326,0.06874684095406326,0.06874684095406326,0.06874684095406326,0.06874684095406326,0.07394656698665387,0.11478227910339048,0.12298101332506123],"y":["date  ","conforms  ","pinpoint  ","iteration  ","breakawayshown  ","latest  ","tracking  ","game  ","legend  ","leather  "],"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666 ...

# %% [markdown]
# # initial BERTopic on non sus descriptions

# %%
topic_model_1 = BERTopic(nr_topics = 5, calculate_probabilities=True, verbose=True)
topics1, probs1 = topic_model_1.fit_transform(non_sus_filtered_descriptions)
# Out:
# 2024-05-01 01:27:41,077 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/19 [00:00<?, ?it/s]
# 2024-05-01 01:28:00,157 - BERTopic - Embedding - Completed ✓
# 2024-05-01 01:28:00,159 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-01 01:28:04,360 - BERTopic - Dimensionality - Completed ✓
# 2024-05-01 01:28:04,361 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-01 01:28:04,411 - BERTopic - Cluster - Completed ✓
# 2024-05-01 01:28:04,413 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-01 01:28:04,487 - BERTopic - Representation - Completed ✓
# 2024-05-01 01:28:04,489 - BERTopic - Topic reduction - Reducing number of topics
# 2024-05-01 01:28:04,555 - BERTopic - Topic reduction - Reduced number of topics from 16 to 5

# %%
topic_model_1.get_document_info(non_sus_data['clean_description']).head()

# %%
topic_model_1.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4af2e472-7be3-4c10-ae22-53be1b2e26ad" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4af2e472-7be3-4c10-ae22-53be1b2e26ad")) {                    Plotly.newPlot(                        "4af2e472-7be3-4c10-ae22-53be1b2e26ad",                        [{"customdata":[[0,"classic | leather | style | jordan | look",178],[1,"help | run | speed | game | foot",152],[2,"slide | foam | strap | team | comfort",54],[3,"description | available | field | dominate | airshown",11]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[178,152,54,11],"sizemode":"area","sizeref":0.11125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.9432917237281799,0.23541441559791565,0.8890525102615356,-0.5196499228477478],"xaxis":"x","y":[0.8572589159011841,0.3046855926513672,1.662882685661316,0.417327344417572],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks" ...

# %%
topic_model_1.visualize_barchart(n_words = 10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52fa989e-5d53-4fd2-9ffd-9d9cf8c013ae" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52fa989e-5d53-4fd2-9ffd-9d9cf8c013ae")) {                    Plotly.newPlot(                        "52fa989e-5d53-4fd2-9ffd-9d9cf8c013ae",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.02334683325444533,0.02528018459912926,0.025885003714266972,0.02600118609660389,0.02927187720906133,0.036759571658891634,0.03695876580332219,0.0376184307789917,0.04067923069136241,0.051376728520301215],"y":["iconic  ","premium  ","icon  ","detail  ","retro  ","look  ","jordan  ","style  ","leather  ","classic  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02051190881594965,0.022163939380159394,0.022764104254565723,0.02399115634697568,0.024141692571909453,0.026087778226157293,0.02649591478945178,0.030349556376114743,0.03060251179711561,0.06291292326650441],"y":["zoom  ","keep  ","day  ","go  ","support  ","foot  ","game  ","speed  ","run  ","help  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.05602353987646612,0.057219164028683746,0.05888176329547191,0.060850295796943385,0.06395402199054681,0.06912821602361276,0.07178618109975284,0.07469260908973527,0.10972726496797192,0.1172313615407547],"y":["never  ","offshown  ","feature  ","innovative  ","midsole  ","comfort  ","team  ","strap  ","foam  ","slide  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.17636955443538063,0.1872758610850803,0.21331528265857855,0.2174248631014345,0.22208508322730666,0.2274662552810791,0.23383242086180864,0.23996096625409438,0.26650209987276796,0.27295950633729493],"y":["fast  ","matter  ","minute  ","waning  ","matchwhen  ","airshown  ","dominate  ","field  ","available  ","description  "],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"# ...

# %% [markdown]
# #sec BERTopic on non sus descriptions

# %%
train_non_sus, test_non_sus = train_test_split(non_sus_filtered_descriptions, test_size=0.5, random_state=41)

# %%
model_non_sus = BERTopic(nr_topics = 5, calculate_probabilities=True, verbose=True)
topics, probs = model_non_sus.fit_transform(train_non_sus)
model_non_sus.fit(test_non_sus)
# Out:
# 2024-05-08 21:50:30,565 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# 2024-05-08 21:50:42,217 - BERTopic - Embedding - Completed ✓
# 2024-05-08 21:50:42,220 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-08 21:50:45,120 - BERTopic - Dimensionality - Completed ✓
# 2024-05-08 21:50:45,122 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-08 21:50:45,151 - BERTopic - Cluster - Completed ✓
# 2024-05-08 21:50:45,154 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-08 21:50:45,198 - BERTopic - Representation - Completed ✓
# 2024-05-08 21:50:45,200 - BERTopic - Topic reduction - Reducing number of topics
# 2024-05-08 21:50:45,253 - BERTopic - Topic reduction - Reduced number of topics from 7 to 5
# 2024-05-08 21:50:45,294 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# 2024-05-08 21:50:55,369 - BERTopic - Embedding - Completed ✓
# 2024-05-08 21:50:55,371 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-08 21:50:58,659 - BERTopic - Dimensionality - Completed ✓
# 2024-05-08 21:50:58,663 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-08 21:50:58,691 - BERTopic - Cluster - Completed ✓
# 2024-05-08 21:50:58,693 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-08 21:50:58,736 - BERTopic - Representation - Completed ✓
# 2024-05-08 21:50:58,738 - BERTopic - Topic reduction - Reducing number of topics
# 2024-05-08 21:50:58,784 - BERTopic - Topic reduction - Reduced number of topics from 8 to 5

# %%
model_non_sus.visualize_barchart(n_words=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="235557a4-7015-4863-928c-4978fc8411f5" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("235557a4-7015-4863-928c-4978fc8411f5")) {                    Plotly.newPlot(                        "235557a4-7015-4863-928c-4978fc8411f5",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.017667555091820622,0.01847991443616108,0.019839786167845323,0.020857574673381212,0.021194785077956465,0.02190977323533878,0.0231277972844818,0.024835985264486677,0.02618795884565265,0.042610063038064035],"y":["comfort  ","return  ","upper  ","cushioning  ","classic  ","keep  ","game  ","speed  ","run  ","help  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.04233205269797996,0.042925874415324264,0.04650284118502282,0.047329005230663024,0.054352485051951074,0.05546562045046829,0.06228839388370015,0.0708588375941367,0.07492803044276794,0.07968750816980695],"y":["experience  ","breathable  ","fit  ","upper  ","provides  ","unit  ","cushioning  ","foam  ","comfort  ","max  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.04863660437150087,0.050270493022148685,0.051116026172182895,0.05462843736656084,0.05710617516201943,0.058332486700348664,0.06082792331366925,0.06477801975723003,0.07791759346255639,0.16881091341477078],"y":["easy  ","element  ","look  ","championship  ","classic  ","got  ","legacy  ","premium  ","redstyle  ","jordan  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.12508753983454743,0.12514969873892987,0.1268129024545547,0.1268129024545547,0.12859179694980258,0.13133293094191514,0.13256943450700814,0.13256943450700814,0.1737228711671169,0.2841890554536215],"y":["foam  ","synthetic  ","never  ","comfy  ","want  ","strap  ","offshown  ","innovative  ","team  ","slide  "],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...

# %% [markdown]
# # BERTopic for reviews

# %%
sus = pd.read_csv('product_reviews.csv')
non_sus = pd.read_csv('product_reviews_all.csv')

# %%
def remove_emojis(text):
    # Unicode ranges for emojis
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F700-\U0001F77F"  # alchemical symbols
                           u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                           u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                           u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                           u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                           u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                           u"\U00002702-\U000027B0"  # Dingbats
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

sus['review'] = sus['review'].apply(remove_emojis)
non_sus['review'] = non_sus['review'].apply(remove_emojis)
sus['review'] = sus['review'].apply(lambda text: preprocess_text(text))
non_sus['review'] = non_sus['review'].apply(lambda text: preprocess_text(text))

# %%
words_to_remove = {'available', 'review', 'url','page', 'please', 'part','instead','collected', 'though', 'af', 'came', 'bur', 'mind', 'excelente', 'luv','tbh', ' ', 'comodos', 'muy'}
non_sus_reviews = [each for each in non_sus['review']]
sus_reviews = [each for each in sus['review']]

sus_reviews = [' '.join(word for word in review.split() if word not in words_to_remove) for review in sus_reviews]
non_sus_reviews = [' '.join(word for word in review.split() if word not in words_to_remove) for review in non_sus_reviews]

# %% [markdown]
# ##initial sus reviews

# %%
topic_model_sus = BERTopic(calculate_probabilities=True, verbose=True)
topics1, probs1 = topic_model_sus.fit_transform(sus_reviews)
# Out:
# 2024-05-01 03:30:57,227 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/19 [00:00<?, ?it/s]
# 2024-05-01 03:31:05,195 - BERTopic - Embedding - Completed ✓
# 2024-05-01 03:31:05,201 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-01 03:31:10,892 - BERTopic - Dimensionality - Completed ✓
# 2024-05-01 03:31:10,894 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-01 03:31:10,937 - BERTopic - Cluster - Completed ✓
# 2024-05-01 03:31:10,944 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-01 03:31:10,973 - BERTopic - Representation - Completed ✓

# %%
topic_model_sus.visualize_barchart(n_words = 10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9dbc0fec-2db8-4507-9e0a-261dae72fd14" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dbc0fec-2db8-4507-9e0a-261dae72fd14")) {                    Plotly.newPlot(                        "9dbc0fec-2db8-4507-9e0a-261dae72fd14",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.040542419165490624,0.04091167266486574,0.041645794322315126,0.042736280055994634,0.04392548369865484,0.053670014084443315,0.0633268503569127,0.06877596982238476,0.06990173560380614,0.07294312951998314],"y":["pair  ","like  ","promotion  ","look  ","good  ","fit  ","great  ","love  ","size  ","comfortable  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[1e-05,1e-05,1e-05,1e-05,1e-05,1e-05,0.9805959308494662,1.0139566372028588,1.0933602913595912,1.2529903375344547],"y":["  ","  ","  ","  ","  ","  ","excellent  ","school  ","great  ","good  "],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmod ...

# %% [markdown]
# ## sec attempt sus reviews

# %%
train_sus1, test_sus1 = train_test_split(sus_reviews, test_size=0.5, random_state=41)

# %%
model_sus1 = BERTopic(calculate_probabilities=True, verbose=True)
topics, probs = model_sus1.fit_transform(train_sus1)
model_sus1.fit(test_sus1)
# Out:
# 2024-05-09 00:07:10,820 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# 2024-05-09 00:07:18,510 - BERTopic - Embedding - Completed ✓
# 2024-05-09 00:07:18,512 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-09 00:07:21,431 - BERTopic - Dimensionality - Completed ✓
# 2024-05-09 00:07:21,433 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-09 00:07:21,459 - BERTopic - Cluster - Completed ✓
# 2024-05-09 00:07:21,466 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-09 00:07:21,488 - BERTopic - Representation - Completed ✓
# 2024-05-09 00:07:21,508 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# 2024-05-09 00:07:25,385 - BERTopic - Embedding - Completed ✓
# 2024-05-09 00:07:25,386 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-09 00:07:29,449 - BERTopic - Dimensionality - Completed ✓
# 2024-05-09 00:07:29,456 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-09 00:07:29,490 - BERTopic - Cluster - Completed ✓
# 2024-05-09 00:07:29,501 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-09 00:07:29,539 - BERTopic - Representation - Completed ✓

# %%
model_sus1.visualize_barchart(n_words=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c0003107-be73-4120-b84d-04ee8aa0a719" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0003107-be73-4120-b84d-04ee8aa0a719")) {                    Plotly.newPlot(                        "c0003107-be73-4120-b84d-04ee8aa0a719",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03992830285005641,0.042041457075809745,0.044552156332301876,0.04478707306658191,0.04478707306658191,0.05069664820924488,0.054833804768359966,0.06830476830296342,0.07151899515603818,0.07309380251065446],"y":["foot  ","like  ","good  ","wear  ","look  ","fit  ","great  ","comfortable  ","size  ","love  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[1e-05,1e-05,1e-05,1e-05,1e-05,1e-05,1e-05,1e-05,1.735700820167702,1.8707359521165534],"y":["  ","  ","  ","  ","  ","  ","  ","  ","great  ","good  "],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type": ...

# %% [markdown]
# ## initial non-sus reviews

# %%
topic_model_non_sus = BERTopic(nr_topics= 5, calculate_probabilities=True, verbose=True)
topics, probs = topic_model_non_sus.fit_transform(non_sus_reviews)
# Out:
# 2024-05-01 03:29:28,913 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/46 [00:00<?, ?it/s]
# 2024-05-01 03:29:51,849 - BERTopic - Embedding - Completed ✓
# 2024-05-01 03:29:51,852 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-01 03:30:01,230 - BERTopic - Dimensionality - Completed ✓
# 2024-05-01 03:30:01,234 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-01 03:30:01,579 - BERTopic - Cluster - Completed ✓
# 2024-05-01 03:30:01,581 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-01 03:30:01,747 - BERTopic - Representation - Completed ✓
# 2024-05-01 03:30:01,749 - BERTopic - Topic reduction - Reducing number of topics
# 2024-05-01 03:30:01,866 - BERTopic - Topic reduction - Reduced number of topics from 33 to 5

# %%
topic_model_non_sus.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8df4b877-653a-4b42-869d-53ec85c026c8" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8df4b877-653a-4b42-869d-53ec85c026c8")) {                    Plotly.newPlot(                        "8df4b877-653a-4b42-869d-53ec85c026c8",                        [{"customdata":[[0,"love | comfortable | size | great | fit",839],[1,"best | awesome | great | beautiful | good",107],[2,"dunk | size | love | color | really",16],[3,"fetch | client | error | failed | found",14]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[839,107,16,14],"sizemode":"area","sizeref":0.524375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.017198197543621063,1.9711204767227173,0.5434028506278992,0.5945621132850647],"xaxis":"x","y":[7.180461883544922,7.025045871734619,6.5142011642456055,7.749251365661621],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside ...

# %%
topic_model_non_sus.visualize_barchart(n_words = 10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="af814fe4-7704-4ae5-ba69-2e8209901346" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af814fe4-7704-4ae5-ba69-2e8209901346")) {                    Plotly.newPlot(                        "af814fe4-7704-4ae5-ba69-2e8209901346",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03023441655793049,0.030495100573823108,0.030983609106614438,0.031057203105645213,0.03136073141275604,0.04375562446343294,0.04612913103889248,0.049160696355188944,0.0510546527750175,0.0593229168678123],"y":["promotion  ","foot  ","look  ","pair  ","wear  ","fit  ","great  ","size  ","comfortable  ","love  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.18422872424942924,0.18422872424942924,0.18422872424942924,0.19175647788037817,0.20494010034069507,0.21420738237575224,0.22566316834552472,0.28046988458530747,0.3107965607070808,0.39385038211940565],"y":["assure  ","perf  ","fence  ","cute  ","ever  ","good  ","beautiful  ","great  ","awesome  ","best  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.04879619683655049,0.05164797432670655,0.05591100323064542,0.061204326846176604,0.0633116360017733,0.07033461267480443,0.07948143361887147,0.1052258125883762,0.11426241951879988,0.4375647018149197],"y":["quality  ","half  ","big  ","keep  ","confusing  ","really  ","color  ","love  ","size  ","dunk  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.07133813839768179,0.0812676470630267,0.09206334359949118,0.09589576078284329,0.10129861760283727,0.887118927485571,0.9570532257627894,0.9801119788104818,0.9929140002166298,0.9929140002166298],"y":["especially  ","ended  ","returning  ","meet  ","collar  ","found  ","failed  ","error  ","client  ","fetch  "],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666, ...

# %% [markdown]
# ##sec attempt non sus reviews

# %%
train_nonsus_r, test_nonsus_r = train_test_split(non_sus_reviews, test_size=0.5, random_state=45)

# %%
topic_model_nonsus = BERTopic(nr_topics = 5, calculate_probabilities=True, verbose=True)
topics_r, probs_r = topic_model_nonsus.fit_transform(train_nonsus_r)
topic_model_nonsus.fit(test_nonsus_r)
# Out:
# 2024-05-09 00:38:36,824 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]
# 2024-05-09 00:38:49,847 - BERTopic - Embedding - Completed ✓
# 2024-05-09 00:38:49,850 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-09 00:38:54,515 - BERTopic - Dimensionality - Completed ✓
# 2024-05-09 00:38:54,517 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-09 00:38:54,573 - BERTopic - Cluster - Completed ✓
# 2024-05-09 00:38:54,575 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-09 00:38:54,610 - BERTopic - Representation - Completed ✓
# 2024-05-09 00:38:54,612 - BERTopic - Topic reduction - Reducing number of topics
# 2024-05-09 00:38:54,617 - BERTopic - Topic reduction - Reduced number of topics from 3 to 3
# 2024-05-09 00:38:54,639 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]
# 2024-05-09 00:39:06,797 - BERTopic - Embedding - Completed ✓
# 2024-05-09 00:39:06,799 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-05-09 00:39:10,946 - BERTopic - Dimensionality - Completed ✓
# 2024-05-09 00:39:10,948 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-05-09 00:39:11,013 - BERTopic - Cluster - Completed ✓
# 2024-05-09 00:39:11,016 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-05-09 00:39:11,061 - BERTopic - Representation - Completed ✓
# 2024-05-09 00:39:11,062 - BERTopic - Topic reduction - Reducing number of topics
# 2024-05-09 00:39:11,065 - BERTopic - Topic reduction - Reduced number of topics from 3 to 3

# %%
topic_model_nonsus.visualize_barchart(n_words=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="53064221-5960-4f15-b8b7-c07e261056cd" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53064221-5960-4f15-b8b7-c07e261056cd")) {                    Plotly.newPlot(                        "53064221-5960-4f15-b8b7-c07e261056cd",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[1e-05,1e-05,1e-05,1e-05,1e-05,1e-05,1e-05,1e-05,1e-05,1e-05],"y":["  ","  ","  ","  ","  ","  ","  ","  ","  ","  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.11624131518375075,0.13454112282257952,0.13454112282257952,0.13454112282257952,0.13454112282257952,0.9062429996561783,0.9185425282962482,0.962114408883902,0.962114408883902,0.962114408883902],"y":["send  ","sent  ","shelf  ","sits  ","display  ","found  ","failed  ","error  ","fetch  ","client  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.0336409184785236,0.034190984672688995,0.035547329359858326,0.03608259000202357,0.04047796174877246,0.04438930317224569,0.05274593877030313,0.05844548592366424,0.05953823483883931,0.06378058529701992],"y":["wear  ","color  ","foot  ","like  ","pair  ","fit  ","great  ","size  ","comfortable  ","love  "],"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111, ...
